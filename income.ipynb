# %%
# generic import
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# retrieve data
from ucimlrepo import fetch_ucirepo, list_available_datasets

sns.set_theme(style="darkgrid")

# %%
adult = fetch_ucirepo(id=2)
X = adult.data.features
y = adult.data.targets
adults_df = pd.concat([X,y], axis=1)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Basic Descriptive Statistics

# %%
adult.metadata.abstract
# Out:
# 'Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset. '

# %%
adult.metadata.repository_url
# Out:
# 'https://archive.ics.uci.edu/dataset/2/adult'

# %%
print(adult.metadata.additional_info.summary)
# Out:
# Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))
#
# Prediction task is to determine whether a person makes over 50K a year.

# %%
adults_df.shape
# Out:
# (48842, 15)

# %%
adults_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
adults_df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.643585  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.710510  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adults_df.isna().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# income              0
# dtype: int64

# %%
adults_df.isna().sum().sum()
# Out:
# 2203

# %% [markdown]
# ### Basic Plots

# %%
# Calculate the proportion of each category
proportions = adults_df['sex'].value_counts(normalize=True)

# Create a DataFrame from the proportions
prop_df = pd.DataFrame({'sex': proportions.index, 'proportion': proportions.values})

# Create the proportion plot
sns.barplot(data=prop_df, x='sex', y='proportion')
plt.show()

# %%
# Calculate the proportion of each category
proportions = adults_df['marital-status'].value_counts(normalize=True)

# Create a DataFrame from the proportions
prop_df = pd.DataFrame({'marital-status': proportions.index, 'proportion': proportions.values})

# Create the proportion plot
sns.barplot(data=prop_df, y='marital-status', x='proportion')
plt.show()

# %%
sns.histplot(adults_df['age'])
plt.title('histogram of age observations')
plt.show()

# %%
sns.histplot(adults_df['education-num'])
plt.title('histogram of age observations')
plt.show()

# %%
sns.histplot(adults_df['capital-gain'])
plt.title('histogram of age observations')
plt.show()

# %%
sns.histplot(adults_df['capital-loss'])
plt.title('histogram of age observations')
plt.show()

# %%
sns.histplot(adults_df['hours-per-week'])
plt.title('histogram of age observations')
plt.show()

# %% [markdown]
# ### Digging in
